# %%
import re

# %%
with open('a.txt', encoding='utf8') as file:
    data = file.read()

# %%
data
# Out:
# '__MLK__\tGần 500 học sinh phải học trong điều kiện tạm bợ (NLĐ)- Gần 500 học sinh Trường Tiểu học Đống Đa, P. 25, quận Bình Thạnh- TPHCM đến nay vẫn phải được gởi học tạm tại 2 nơi cách nhà khoảng 5 km do ngôi trường này đã xuống cấp trầm trọng. Theo kế hoạch, đầu năm học 2005-2006, Trường Tiểu học Đống Đa được khởi công xây dựng để sang năm các em có chỗ học, nhưng điều đáng nói là đến nay, năm học gần kết thúc, vẫn chưa thấy xây trường. Nhiều phụ huynh cảm thấy không yên tâm khi hằng ngày con em họ phải học trong tình trạng trường lớp tạm bợ và đi lại kém an toàn như thế. \n__CTXH__\tNgầm hóa các công trình hạ tầng kỹ thuật Theo đó, UBND TP chấp thuận giao Khu quản lý giao thông đô thị số 1 phối hợp các đơn vị quản lý chuyên ngành di dời, tái lập các công trình hạ tầng kỹ thuật thuộc phạm vi qui hoạch xây dựng của dự án theo phương án ngầm hóa riêng biệt từng loại công trình (cáp quang bưu điện - truyền thông, điện lực, cấp nước...). UBND TP cũng chấp thuận cho Bưu điện TP nghiên 
# ...

# %%
# find =  re.findall(r"(?=(__\w+__))", data)
# print(find)

# %%
d= data.split('\n')

# %%
find =  re.findall(r"(?=(__\w+__))", data)
print(find)
# Out:
# ['__MLK__', '__CTXH__', '__HHLH__', '__CTXH__', '__CTXH__', '__CTXH__', '__KTHH__', '__CT__', '__CTXH__']

# %%
for i in d:
    meh=[]
    for k in range(len(find)):
        res = re.sub(find[k], "", i)
    meh.append(res)
print(meh[0])
print(len(meh))
# Out:
# 	Đưa vào hoạt động website Festival Biển Trang website này ra đời nhằm cung cấp thông tin cần thiết cho du khách và người dân địa phương những hoạt động liên quan đến festival biển Bà Rịa - Vũng Tàu như: Hội trại điêu khắc đá, lễ hội bắn súng thần công, hội chợ triển lãm, Liên hoan ẩm thực, Đắp tượng cát, Nhảy dù nghệ thuật, Biểu diễn thể thao biển, Cuộc thi Hoa hậu Festival biển, Chương trình ca múa nhạc thời trang, biểu diễn nhạc nước, Lễ khai mạc và bế mạc… Ngoài những thông tin về Festival Biển 2006, website này còn cung cấp các thông tin về giá cả các dịch vụ lưu trú, ăn uống, giải trí, đi lại… tại Bà Rịa Vũng Tàu. Khi truy cập vào website www.festivalbien.com , khách hàng có thể tìm hiểu thêm các danh lam thắng cảnh, di tích lịch sử - văn hóa, các tuyến điểm tham quan, tiềm năng phát triển kinh tế biển của Bà Rịa Vũng Tàu. Đặc biệt, website này còn mở một hỗ trợ trực tuyến qua Internet và đường dây điện thoại nóng để đáp ứng nhu cầu thông tin, trả lời những thắc mắc của du khác
# ...

# %%
meh
# Out:
# ['__MLK__\tGần 500 học sinh phải học trong điều kiện tạm bợ (NLĐ)- Gần 500 học sinh Trường Tiểu học Đống Đa, P. 25, quận Bình Thạnh- TPHCM đến nay vẫn phải được gởi học tạm tại 2 nơi cách nhà khoảng 5 km do ngôi trường này đã xuống cấp trầm trọng. Theo kế hoạch, đầu năm học 2005-2006, Trường Tiểu học Đống Đa được khởi công xây dựng để sang năm các em có chỗ học, nhưng điều đáng nói là đến nay, năm học gần kết thúc, vẫn chưa thấy xây trường. Nhiều phụ huynh cảm thấy không yên tâm khi hằng ngày con em họ phải học trong tình trạng trường lớp tạm bợ và đi lại kém an toàn như thế. ',
# ...
